# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import time 
# %matplotlib inline

# %%
import tensorflow as tf
hello=tf.constant('hello')
world=tf.constant('world')
hellowd=tf.add(hello,world)
#init_op=tf.global_variables_intializer()
sess=tf.Session()
#sess.run(init_op)
print(sess.run(hellowd))
# Out:
# b'helloworld'

# %%
import tensorflow as tf
a=tf.placeholder(tf.float32)
b=a*2
sess=tf.Session()
#result=sess.run(b,feed_dict={a:3})
dictionary={a:[[1,2,3],[4,5,6],[7,8,9]]}
#result=sess.run(b,feed_dict={a:[3,4,5]})
result=sess.run(b,feed_dict=dictionary)
print(result)
# Out:
# [[ 2.  4.  6.]
#  [ 8. 10. 12.]
#  [14. 16. 18.]]

# %%
#another type for intialisation session
import tensorflow as tf
hello=tf.constant('hello')
world=tf.constant('world')
with tf.Session() as sess:
    result=sess.run(hello+world)
    print(result)
# Out:
# b'helloworld'

# %%
import tensorflow as tf
graph=tf.get_default_graph()
a=tf.constant(5,name='hello') #mostly used for graph build
b=tf.constant(6,name='world')
c=tf.add(a,b,"c")
operations=graph.get_operations()# still we are generating the graph
c #still there is no running of program through session
for op in graph.get_operations():
    print(op.name) # run in separate notebook
# Out:
# Placeholder
# mul/y
# mul
# Placeholder_1
# mul_1/y
# mul_1
# Placeholder_2
# mul_2/y
# mul_2
# Placeholder_3
# mul_3/y
# mul_3
# Placeholder_4
# mul_4/y
# mul_4
# Placeholder_5
# mul_5/y
# mul_5
# Const
# Const_1
# add
# hello
# hello_1
# world
# c
# hello_2
# world_1
# c_1
# hello_3
# world_2
# c_2
# hello_4
# world_3
# c_3
# hello_5
# world_4
# c_4
# hello_6
# world_5
# c_5
# hello_7
# world_6
# c_6

# %%
import tensorflow as tf
#graph=tf.get_default_graph()
a=tf.constant(5,name='a') #mostly used for graph build
b=tf.constant(6,name='b')
c=tf.add(a,b,"c")
d=tf.multiply(a,b,"d")
sess=tf.Session()
print(sess.run(d))
# Out:
# 30

# %%
from sklearn import svm
clf=svm.SVC(kernel="linear", C=1000)

# %%
import cv2, glob, time

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import time 
# %matplotlib inline
test1 = cv2.imread('C:\\Users\\Venkatesan R\\Pictures\\test3.jpg')
#plt.imshow(test1, cmap='gray')
gray_img = cv2.cvtColor(test1, cv2.COLOR_BGR2GRAY)
face_cascade = cv2.CascadeClassifier("G:\\Face-Detection-OpenCV-master\\Face-Detection-OpenCV-master\\data\\haarcascade_frontalface_alt.xml")
faces = face_cascade.detectMultiScale(gray_img, scaleFactor=1.05, minNeighbors=5);
print('Faces found: ', len(faces))
for (x, y, w, h) in faces:
    cv2.rectangle(test1, (x, y), (x+w, y+h), (0, 255, 0), 2)
    
    
    #conver image to RGB and show image
#plt.imshow(convertToRGB(test1))
# Out:
# Faces found:  3

# %%
def convertToRGB(img):
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
#conver image to RGB and show image
plt.imshow(convertToRGB(test1))
