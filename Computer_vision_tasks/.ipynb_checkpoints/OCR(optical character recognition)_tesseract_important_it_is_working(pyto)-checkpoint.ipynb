# %%
from pytesseract import pytesseract
from PIL import Image

# %%
pytesseract.tesseract_cmd="C:\\Users\\Venkatesan R\\AppData\\Local\\Programs\\Tesseract-OCR\\tesseract.exe"

# %%
from matplotlib import pyplot as plt
import cv2

# %%
path1="C:\\Users\\Venkatesan R\\Pictures\\Motivational-Quote-on-Dont-Quit.jpg"
img= cv2.imread(path1, 0) 
#ground_truth_img = cv2.resize(ground_truth_img, (SIZE, SIZE))
print(img.shape)
print(img.ndim)
print(img.min(),img.max())
print(img.shape)
plt.imshow(img,cmap=plt.cm.gray)
plt.show()
# Out:
# (297, 300)
# 2
# 3 255
# (297, 300)

# %%
print(pytesseract.image_to_string(Image.open('C:\\Users\\Venkatesan R\\Pictures\\Motivational-Quote-on-Dont-Quit.jpg')))
# Out:
# IF YOU
# FEBIBWIKE
# QUITTING
# THINK ABOUT
#
# WHY YOU
# STARTED.
