# %%
# File location and type
file_location = "/FileStore/tables/test1.csv"
file_location = "/FileStore/tables/tips.csv"
file_location = "/FileStore/tables/hcvdata.csv"

file_type = "csv"

df=spark.read.csv(file_location, header=True, inferSchema=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Load PySPark
from pyspark import SparkContext
import pyspark
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dir(pyspark)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [&#39;Accumulator&#39;,
#  &#39;AccumulatorParam&#39;,
#  &#39;BarrierTaskContext&#39;,
#  &#39;BarrierTaskInfo&#39;,
#  &#39;BasicProfiler&#39;,
#  &#39;Broadcast&#39;,
#  &#39;HiveContext&#39;,
#  &#39;InheritableThread&#39;,
#  &#39;MarshalSerializer&#39;,
#  &#39;PickleSerializer&#39;,
#  &#39;Profiler&#39;,
#  &#39;RDD&#39;,
#  &#39;RDDBarrier&#39;,
#  &#39;Row&#39;,
#  &#39;SQLContext&#39;,
#  &#39;SparkConf&#39;,
#  &#39;SparkContext&#39;,
#  &#39;SparkFiles&#39;,
#  &#39;SparkJobInfo&#39;,
#  &#39;SparkStageInfo&#39;,
#  &#39;StatusTracker&#39;,
#  &#39;StorageLevel&#39;,
#  &#39;TaskContext&#39;,
#  &#39;_NoValue&#39;,
#  &#39;__all__&#39;,
#  &#39;__builtins__&#39;,
#  &#39;__cached__&#39;,
#  &#39;__doc__&#39;,
#  &#39;__file__&#39;,
#  &#39;__loader__&#39;,
#  &#39;__name__&#39;,
#  &#39;__package__&#39;,
#  &#39;__path__&#39;,
#  &#39;__spec__&#39;,
#  &#39;__version__&#39;,
#  &#39;_globals&#39;,
#  &#39;accumulators&#39;,
#  &#39;broadcast&#39;,
#  &#39;cloudpickle&#39;,
#  &#39;conf&#39;,
#  &#39;context&#39;,
#  &#39;copy_func&#39;,
#  &#39;databricks&#39;,
#  &#39;files&#39;,
#  &#39;find_spark_home&#39;,
#  &#39;inheritable_thread_target&#39;,
#  &#39;java_gateway&#39;,
#  &#39;join&#39;,
#  &#39;keyword_only&#39;,
#  &#39;profiler&#39;,
#  &#39;rdd&#39;,
#  &#39;rddsampler&#39;,
#  &#39;resource&#39;,
#  &#39;resultiterable&#39;,
#  &#39;serializers&#39;,
#  &#39;shuffle&#39;,
#  &#39;since&#39;,
#  &#39;sql&#39;,
#  &#39;statcounter&#39;,
#  &#39;status&#39;,
#  &#39;storagelevel&#39;,
#  &#39;taskcontext&#39;,
#  &#39;traceback_utils&#39;,
#  &#39;types&#39;,
#  &#39;util&#39;,
#  &#39;version&#39;,
#  &#39;wraps&#39;]</div>

# %%
# Get  5 Head
df.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: [Row(_c0=1, Category=&#39;0=Blood Donor&#39;, Age=32, Sex=&#39;m&#39;, ALB=&#39;38.5&#39;, ALP=&#39;52.5&#39;, ALT=&#39;7.7&#39;, AST=22.1, BIL=7.5, CHE=6.93, CHOL=&#39;3.23&#39;, CREA=106.0, GGT=12.1, PROT=&#39;69&#39;),
#  Row(_c0=2, Category=&#39;0=Blood Donor&#39;, Age=32, Sex=&#39;m&#39;, ALB=&#39;38.5&#39;, ALP=&#39;70.3&#39;, ALT=&#39;18&#39;, AST=24.7, BIL=3.9, CHE=11.17, CHOL=&#39;4.8&#39;, CREA=74.0, GGT=15.6, PROT=&#39;76.5&#39;),
#  Row(_c0=3, Category=&#39;0=Blood Donor&#39;, Age=32, Sex=&#39;m&#39;, ALB=&#39;46.9&#39;, ALP=&#39;74.7&#39;, ALT=&#39;36.2&#39;, AST=52.6, BIL=6.1, CHE=8.84, CHOL=&#39;5.2&#39;, CREA=86.0, GGT=33.2, PROT=&#39;79.3&#39;),
#  Row(_c0=4, Category=&#39;0=Blood Donor&#39;, Age=32, Sex=&#39;m&#39;, ALB=&#39;43.2&#39;, ALP=&#39;52&#39;, ALT=&#39;30.6&#39;, AST=22.6, BIL=18.9, CHE=7.33, CHOL=&#39;4.74&#39;, CREA=80.0, GGT=33.8, PROT=&#39;75.7&#39;),
#  Row(_c0=5, Category=&#39;0=Blood Donor&#39;, Age=32, Sex=&#39;m&#39;, ALB=&#39;39.2&#39;, ALP=&#39;74.1&#39;, ALT=&#39;32.6&#39;, AST=24.8, BIL=9.6, CHE=9.15, CHOL=&#39;4.32&#39;, CREA=76.0, GGT=29.9, PROT=&#39;68.7&#39;)]</div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: integer (nullable = true)
# -- Category: string (nullable = true)
# -- Age: integer (nullable = true)
# -- Sex: string (nullable = true)
# -- ALB: string (nullable = true)
# -- ALP: string (nullable = true)
# -- ALT: string (nullable = true)
# -- AST: double (nullable = true)
# -- BIL: double (nullable = true)
# -- CHE: double (nullable = true)
# -- CHOL: string (nullable = true)
# -- CREA: double (nullable = true)
# -- GGT: double (nullable = true)
# -- PROT: string (nullable = true)
#
# </div>

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-------------+---+---+----+----+----+----+----+-----+----+-----+----+----+
# _c0|     Category|Age|Sex| ALB| ALP| ALT| AST| BIL|  CHE|CHOL| CREA| GGT|PROT|
# +---+-------------+---+---+----+----+----+----+----+-----+----+-----+----+----+
#   1|0=Blood Donor| 32|  m|38.5|52.5| 7.7|22.1| 7.5| 6.93|3.23|106.0|12.1|  69|
#   2|0=Blood Donor| 32|  m|38.5|70.3|  18|24.7| 3.9|11.17| 4.8| 74.0|15.6|76.5|
#   3|0=Blood Donor| 32|  m|46.9|74.7|36.2|52.6| 6.1| 8.84| 5.2| 86.0|33.2|79.3|
#   4|0=Blood Donor| 32|  m|43.2|  52|30.6|22.6|18.9| 7.33|4.74| 80.0|33.8|75.7|
#   5|0=Blood Donor| 32|  m|39.2|74.1|32.6|24.8| 9.6| 9.15|4.32| 76.0|29.9|68.7|
#   6|0=Blood Donor| 32|  m|41.6|43.3|18.5|19.7|12.3| 9.92|6.05|111.0|91.0|  74|
#   7|0=Blood Donor| 32|  m|46.3|41.3|17.5|17.8| 8.5| 7.01|4.79| 70.0|16.9|74.5|
#   8|0=Blood Donor| 32|  m|42.2|41.9|35.8|31.1|16.1| 5.82| 4.6|109.0|21.5|67.1|
#   9|0=Blood Donor| 32|  m|50.9|65.5|23.2|21.2| 6.9| 8.69| 4.1| 83.0|13.7|71.3|
#  10|0=Blood Donor| 32|  m|42.4|86.3|20.3|20.0|35.2| 5.46|4.45| 81.0|15.9|69.9|
#  11|0=Blood Donor| 32|  m|44.3|52.3|21.7|22.4|17.2| 4.15|3.57| 78.0|24.1|75.4|
#  12|0=Blood Donor| 33|  m|46.4|68.2|10.3|20.0| 5.7| 7.36| 4.3| 79.0|18.7|68.6|
#  13|0=Blood Donor| 33|  m|36.3|78.6|23.6|22.0| 7.0| 8.56|5.38| 78.0|19.4|68.7|
#  14|0=Blood Donor| 33|  m|  39|51.7|15.9|24.0| 6.8| 6.46|3.38| 65.0| 7.0|70.4|
#  15|0=Blood Donor| 33|  m|38.7|39.8|22.5|23.0| 4.1| 4.63|4.97| 63.0|15.2|71.9|
#  16|0=Blood Donor| 33|  m|41.8|  65|33.1|38.0| 6.6| 8.83|4.43| 71.0|24.0|72.7|
#  17|0=Blood Donor| 33|  m|40.9|  73|17.2|22.9|10.0| 6.98|5.22| 90.0|14.7|72.4|
#  18|0=Blood Donor| 33|  m|45.2|88.3|32.4|31.2|10.1| 9.78|5.51|102.0|48.5|76.5|
#  19|0=Blood Donor| 33|  m|36.6|57.1|38.9|40.3|24.9| 9.62| 5.5|112.0|27.6|69.3|
#  20|0=Blood Donor| 33|  m|  42|63.1|32.6|34.9|11.2| 7.01|4.05|105.0|19.1|68.1|
# +---+-------------+---+---+----+----+----+----+----+-----+----+-----+----+----+
# only showing top 20 rows
#
# </div>

# %%
# Get First Row
df.first()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: Row(_c0=1, Category=&#39;0=Blood Donor&#39;, Age=32, Sex=&#39;m&#39;, ALB=&#39;38.5&#39;, ALP=&#39;52.5&#39;, ALT=&#39;7.7&#39;, AST=22.1, BIL=7.5, CHE=6.93, CHOL=&#39;3.23&#39;, CREA=106.0, GGT=12.1, PROT=&#39;69&#39;)</div>

# %%
# Check For the column names
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: [&#39;_c0&#39;,
#  &#39;Category&#39;,
#  &#39;Age&#39;,
#  &#39;Sex&#39;,
#  &#39;ALB&#39;,
#  &#39;ALP&#39;,
#  &#39;ALT&#39;,
#  &#39;AST&#39;,
#  &#39;BIL&#39;,
#  &#39;CHE&#39;,
#  &#39;CHOL&#39;,
#  &#39;CREA&#39;,
#  &#39;GGT&#39;,
#  &#39;PROT&#39;]</div>

# %%
# Check the number of rows
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: 615</div>

# %%
# Check for the columns
len(df.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: 14</div>

# %%
# Get the shape (rows,cols)
print(df.count(),len(df.columns))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">615 14
# </div>

# %%
df.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+-------------+------------------+----+-----------------+------------------+------------------+-----------------+------------------+------------------+------------------+-----------------+-----------------+-----------------+
# summary|               _c0|     Category|               Age| Sex|              ALB|               ALP|               ALT|              AST|               BIL|               CHE|              CHOL|             CREA|              GGT|             PROT|
# +-------+------------------+-------------+------------------+----+-----------------+------------------+------------------+-----------------+------------------+------------------+------------------+-----------------+-----------------+-----------------+
#   count|               615|          615|               615| 615|              615|               615|               615|              615|               615|               615|               615|              615|              615|              615|
#    mean|             308.0|         null| 47.40813008130081|null|41.62019543973941| 68.28391959798999| 28.45081433224754|34.78634146341462|11.396747967479675| 8.196634146341458| 5.368099173553719|81.28780487804877|39.53317073170732|72.04413680781768|
#  stddev|177.67948671695333|         null|10.055105445519239|null|5.780629404103076|26.028315300123676|25.469688813870942|33.09069033855156|19.673149805846588|2.2056572704292927|1.1327284311597354|49.75616601234976|54.66107123891245|5.402635737104955|
#     min|                 1|0=Blood Donor|                19|   f|             14.9|             100.4|               0.9|             10.6|               0.8|              1.42|              1.43|              8.0|              4.5|             44.8|
#     max|               615|  3=Cirrhosis|                77|   m|               NA|                NA|                NA|            324.0|             254.0|             16.41|                NA|           1079.1|            650.9|               NA|
# +-------+------------------+-------------+------------------+----+-----------------+------------------+------------------+-----------------+------------------+------------------+------------------+-----------------+-----------------+-----------------+
#
# </div>

# %%
# Get Descriptive Summary of A Column
df.describe('age').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+
# summary|               age|
# +-------+------------------+
#   count|               615|
#    mean| 47.40813008130081|
#  stddev|10.055105445519239|
#     min|                19|
#     max|                77|
# +-------+------------------+
#
# </div>

# %%
df.select('age').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+
# age|
# +---+
#  32|
#  32|
#  32|
#  32|
#  32|
#  32|
#  32|
#  32|
#  32|
#  32|
#  32|
#  33|
#  33|
#  33|
#  33|
#  33|
#  33|
#  33|
#  33|
#  33|
# +---+
# only showing top 20 rows
#
# </div>

# %%
# Select Multiple columnns
df.select('Age','Category').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-------------+
# Age|     Category|
# +---+-------------+
#  32|0=Blood Donor|
#  32|0=Blood Donor|
#  32|0=Blood Donor|
#  32|0=Blood Donor|
#  32|0=Blood Donor|
#  32|0=Blood Donor|
#  32|0=Blood Donor|
#  32|0=Blood Donor|
#  32|0=Blood Donor|
#  32|0=Blood Donor|
#  32|0=Blood Donor|
#  33|0=Blood Donor|
#  33|0=Blood Donor|
#  33|0=Blood Donor|
#  33|0=Blood Donor|
#  33|0=Blood Donor|
#  33|0=Blood Donor|
#  33|0=Blood Donor|
#  33|0=Blood Donor|
#  33|0=Blood Donor|
# +---+-------------+
# only showing top 20 rows
#
# </div>

# %%
# Filter : Method 1
df.filter(df.Age == 25).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-----------+---+---+---+----+----+-----+----+---+----+----+----+----+
# _c0|   Category|Age|Sex|ALB| ALP| ALT|  AST| BIL|CHE|CHOL|CREA| GGT|PROT|
# +---+-----------+---+---+---+----+----+-----+----+---+----+----+----+----+
# 544|1=Hepatitis| 25|  m| 42|38.2|63.3|187.7|14.0|6.0|4.28|66.9|40.2|70.5|
# +---+-----------+---+---+---+----+----+-----+----+---+----+----+----+----+
#
# </div>

# %%
# Where: Method 1
df.where(df['sex'] == 'f').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-------------+---+---+----+-----+----+----+----+-----+----+----+----+----+
# _c0|     Category|Age|Sex| ALB|  ALP| ALT| AST| BIL|  CHE|CHOL|CREA| GGT|PROT|
# +---+-------------+---+---+----+-----+----+----+----+-----+----+----+----+----+
# 319|0=Blood Donor| 32|  f|39.9| 35.2|  22|29.8| 6.3| 8.16|4.37|60.0| 4.5|72.5|
# 320|0=Blood Donor| 32|  f|47.4| 52.5|19.1|17.1| 4.6|10.19|  NA|63.0|23.0|72.2|
# 321|0=Blood Donor| 32|  f|41.1| 42.8|10.1|14.1|23.2| 6.08|3.75|53.0| 9.3|68.9|
# 322|0=Blood Donor| 32|  f|43.5| 66.2| 9.2|17.8| 5.7| 7.14|4.38|71.0|44.6|76.1|
# 323|0=Blood Donor| 33|  f|  36| 77.5|14.8|22.0| 4.4| 8.61|5.26|66.0|13.1|66.1|
# 324|0=Blood Donor| 33|  f|36.9| 51.7|17.4|22.0| 8.3|  7.0|5.02|52.0|19.1|  72|
# 325|0=Blood Donor| 33|  f|44.3|   74|49.7|52.3| 8.5| 6.49|3.34|73.0|44.7|73.8|
# 326|0=Blood Donor| 33|  f|38.1| 35.2|11.9|18.3| 3.0| 6.09|5.22|76.0|15.4|  72|
# 327|0=Blood Donor| 33|  f|  41| 61.1|  27|28.0| 6.0| 8.36|4.93|70.0|24.7|70.5|
# 328|0=Blood Donor| 33|  f|38.2| 54.4|17.3|21.2| 7.1| 8.67|5.69|68.0|32.1|66.9|
# 329|0=Blood Donor| 33|  f|47.6| 95.5|18.8|22.2| 2.4| 7.84|5.57|71.0|16.9|  75|
# 330|0=Blood Donor| 33|  f|42.4|137.2|14.2|13.1| 3.4| 8.23|  NA|48.0|25.7|74.4|
# 331|0=Blood Donor| 33|  f|45.9|   72|37.8|33.5|17.7| 7.32|4.25|81.0|21.5|78.3|
# 332|0=Blood Donor| 33|  f|35.4| 53.5| 9.8|17.6| 3.8|  6.0|4.48|78.0| 8.0|71.5|
# 333|0=Blood Donor| 33|  f|38.5| 82.2|11.9|17.0| 7.3| 7.23|3.92|50.0| 7.0|73.3|
# 334|0=Blood Donor| 33|  f|41.2| 73.1|14.3|20.8|11.1|  7.4|3.22|56.0|11.4|69.9|
# 335|0=Blood Donor| 33|  f|40.6| 73.7|12.6|16.3| 3.1| 7.75|6.36|67.0|19.5|71.4|
# 336|0=Blood Donor| 34|  f|37.3| 36.3|19.9|28.7| 3.8|  3.9|4.94|86.0| 4.9|70.7|
# 337|0=Blood Donor| 34|  f|41.9| 47.4|20.8|28.5| 8.0| 7.66|4.61|97.0|11.2|71.9|
# 338|0=Blood Donor| 34|  f|36.3| 63.2|21.4|20.4| 4.6| 7.41|5.17|75.0|18.7|64.2|
# +---+-------------+---+---+----+-----+----+----+----+-----+----+----+----+----+
# only showing top 20 rows
#
# </div>

# %%
#### Working with SQL and Making SQL
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql import SQLContext
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.registerTempTable('HCVTable')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sqlContext.sql('SELECT * FROM HCVTable').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-------------+---+---+----+----+----+----+----+-----+----+-----+----+----+
# _c0|     Category|Age|Sex| ALB| ALP| ALT| AST| BIL|  CHE|CHOL| CREA| GGT|PROT|
# +---+-------------+---+---+----+----+----+----+----+-----+----+-----+----+----+
#   1|0=Blood Donor| 32|  m|38.5|52.5| 7.7|22.1| 7.5| 6.93|3.23|106.0|12.1|  69|
#   2|0=Blood Donor| 32|  m|38.5|70.3|  18|24.7| 3.9|11.17| 4.8| 74.0|15.6|76.5|
#   3|0=Blood Donor| 32|  m|46.9|74.7|36.2|52.6| 6.1| 8.84| 5.2| 86.0|33.2|79.3|
#   4|0=Blood Donor| 32|  m|43.2|  52|30.6|22.6|18.9| 7.33|4.74| 80.0|33.8|75.7|
#   5|0=Blood Donor| 32|  m|39.2|74.1|32.6|24.8| 9.6| 9.15|4.32| 76.0|29.9|68.7|
#   6|0=Blood Donor| 32|  m|41.6|43.3|18.5|19.7|12.3| 9.92|6.05|111.0|91.0|  74|
#   7|0=Blood Donor| 32|  m|46.3|41.3|17.5|17.8| 8.5| 7.01|4.79| 70.0|16.9|74.5|
#   8|0=Blood Donor| 32|  m|42.2|41.9|35.8|31.1|16.1| 5.82| 4.6|109.0|21.5|67.1|
#   9|0=Blood Donor| 32|  m|50.9|65.5|23.2|21.2| 6.9| 8.69| 4.1| 83.0|13.7|71.3|
#  10|0=Blood Donor| 32|  m|42.4|86.3|20.3|20.0|35.2| 5.46|4.45| 81.0|15.9|69.9|
#  11|0=Blood Donor| 32|  m|44.3|52.3|21.7|22.4|17.2| 4.15|3.57| 78.0|24.1|75.4|
#  12|0=Blood Donor| 33|  m|46.4|68.2|10.3|20.0| 5.7| 7.36| 4.3| 79.0|18.7|68.6|
#  13|0=Blood Donor| 33|  m|36.3|78.6|23.6|22.0| 7.0| 8.56|5.38| 78.0|19.4|68.7|
#  14|0=Blood Donor| 33|  m|  39|51.7|15.9|24.0| 6.8| 6.46|3.38| 65.0| 7.0|70.4|
#  15|0=Blood Donor| 33|  m|38.7|39.8|22.5|23.0| 4.1| 4.63|4.97| 63.0|15.2|71.9|
#  16|0=Blood Donor| 33|  m|41.8|  65|33.1|38.0| 6.6| 8.83|4.43| 71.0|24.0|72.7|
#  17|0=Blood Donor| 33|  m|40.9|  73|17.2|22.9|10.0| 6.98|5.22| 90.0|14.7|72.4|
#  18|0=Blood Donor| 33|  m|45.2|88.3|32.4|31.2|10.1| 9.78|5.51|102.0|48.5|76.5|
#  19|0=Blood Donor| 33|  m|36.6|57.1|38.9|40.3|24.9| 9.62| 5.5|112.0|27.6|69.3|
#  20|0=Blood Donor| 33|  m|  42|63.1|32.6|34.9|11.2| 7.01|4.05|105.0|19.1|68.1|
# +---+-------------+---+---+----+----+----+----+----+-----+----+-----+----+----+
# only showing top 20 rows
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
